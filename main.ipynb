# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mat

df = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/FIFA 19/data.csv')
fifa20 = pd.read_csv("C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/FIFA 20/fifa20_data.csv")
# Out:
# C:\Users\Mehak\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (74) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fifa20.columns
# Out:
# Index(['Name', 'Image', 'Country', 'Position', 'Age', 'Overall', 'Potential',
#        'Club', 'ID', 'Height', 'Weight', 'foot', 'BOV', 'BP', 'Growth',
#        'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa20.head()
# Out:
#                            Name  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2    Neymar da Silva Santos Jr.
# 3                     Jan Oblak
# 4               Kevin De Bruyne
#
#                                             Image    Country  Position  Age  \
# 0  https://cdn.sofifa.org/players/4/20/158023.png  Argentina  RW,CF,ST   32
# 1   https://cdn.sofifa.org/players/4/20/20801.png   Portugal     ST,LW   34
# 2  https://cdn.sofifa.org/players/4/20/190871.png     Brazil    LW,CAM   27
# 3  https://cdn.sofifa.org/players/4/20/200389.png   Slovenia        GK   26
# 4  https://cdn.sofifa.org/players/4/20/192985.png    Belgium    CAM,CM   28
#
#    Overall  Potential                 Club      ID Height  ...     A/W  \
# 0       94         94         FC Barcelona  158023   5'7"  ...  Medium
# 1       93         93             Juventus   20801   6'2"  ...    High
# 2       92         92  Paris Saint-Germain  190871   5'9"  ...    High
# 3       91         91      Atlético Madrid  200389   6'2"  ...  Medium
# 4       91         91      Manchester City  192985  5'11"  ...    High
#
#       D/W  IR PAC  SHO PAS DRI DEF PHY Hits
# 0     Low   5  87   92  92  96  39  66  585
# 1     Low   5  90   93  82  89  35  78  448
# 2  Medium   5  91   85  87  95  32  58  432
# 3  Medium   3  87   92  78  89  52  90  240
# 4    High   4  76   86  92  86  61  78  298
#
# [5 rows x 75 columns]

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
df=df.drop(df[['ID','Unnamed: 0','Value','Height','Weight','Wage','Weak Foot','Special','Preferred Foot','Skill Moves','Work Rate','Body Type','Photo','Nationality','Flag','Club Logo','Real Face','Jersey Number','Joined','Loaned From','Contract Valid Until','Release Clause']],axis=1)

# %%
difcol20 = fifa20.columns.difference(df.columns)
difcol19 = df.columns.difference(fifa20.columns)

# %%
difcol20
# Out:
# Index(['A/W', 'Attacking', 'BOV', 'BP', 'Ball Control', 'Base Stats',
#        'Country', 'D/W', 'DEF', 'DRI', 'Defending', 'FK Accuracy', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
#        'Goalkeeping', 'Growth', 'Heading Accuracy', 'Height', 'Hits', 'ID',
#        'IR', 'Image', 'Joined', 'Loan Date End', 'Long Passing', 'Long Shots',
#        'Mentality', 'Movement', 'PAC', 'PAS', 'PHY', 'Power', 'Release Clause',
#        'SHO', 'SM', 'Short Passing', 'Shot Power', 'Skill', 'Sliding Tackle',
#        'Sprint Speed', 'Standing Tackle', 'Total Stats', 'Value', 'W/F',
#        'Wage', 'Weight', 'foot'],
#       dtype='object')

# %%
difcol19
# Out:
# Index(['BallControl', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'FKAccuracy', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'HeadingAccuracy', 'International Reputation', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'LongPassing', 'LongShots',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST',
#        'ShortPassing', 'ShotPower', 'SlidingTackle', 'SprintSpeed',
#        'StandingTackle'],
#       dtype='object')

# %%
fifa20.rename(columns={'Ball Control': 'BallControl', 'FK Accuracy': 'FKAccuracy','GK Diving':'GKDiving','GK Handling':'GKHandling','GK Positioning':'GKPositioning','GK Reflexes':'GKReflexes','Heading Accuracy':'HeadingAccuracy','Short Passing':'ShortPassing','Shot Power':'ShotPower','Sliding Tackle':'SlidingTackle','Sprint Speed':'SprintSpeed','Standing Tackle':'StandingTackle','Long Passing':'LongPassing','Long Shots':'LongShots'}, inplace=True)
difcol20 = fifa20.columns.difference(df.columns)
fifa20=fifa20.drop(fifa20[difcol20],axis=1)
difcol19 = df.columns.difference(fifa20.columns)
df=df.drop(df[difcol19],axis=1)

# %%
fifa20.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Overall', 'Potential', 'Club', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Overall', 'Potential', 'Club', 'Position', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
difcol20 = fifa20.columns.difference(df.columns)
difcol20
# Out:
# Index([], dtype='object')

# %%
difcol19 = df.columns.difference(fifa20.columns)
difcol19
# Out:
# Index([], dtype='object')

# %%
df['New Position']=0
df['New Position'][df['Position']=='GK']='GK'
fifa20['New Position']=0
fifa20['New Position'][fifa20['Position']=='GK']='GK'
# Out:
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
gk19 = df[df['New Position']=='GK']
gk20 = fifa20[fifa20['New Position']=='GK']

# %%
gk20.head()
# Out:
#                          Name Position  Age  Overall  Potential  \
# 3                   Jan Oblak       GK   26       91         91
# 8       Marc-André ter Stegen       GK   27       90         90
# 12      Alisson Ramses Becker       GK   26       89         89
# 16      David De Gea Quintana       GK   28       89         89
# 24  Ederson Santana de Moraes       GK   25       88         88
#
#                  Club  Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# 3     Atlético Madrid        13         11               15            43
# 8        FC Barcelona        18         14               11            61
# 12          Liverpool        17         13               19            45
# 16  Manchester United        17         13               21            50
# 24    Manchester City        20         14               14            56
#
#     ...  Penalties  Composure  Marking  StandingTackle  SlidingTackle  \
# 3   ...         11         68       27              12             18
# 8   ...         25         70       25              13             10
# 12  ...         23         65       15              19             16
# 16  ...         29         68       25              21             13
# 24  ...         17         70       29              15              8
#
#     GKDiving  GKHandling  GKPositioning  GKReflexes  New Position
# 3         87          92             90          89            GK
# 8         88          85             88          90            GK
# 12        85          84             90          89            GK
# 16        90          84             85          92            GK
# 24        86          82             86          88            GK
#
# [5 rows x 40 columns]

# %%
gk19.head()
# Out:
#              Name  Age  Overall  Potential               Club Position  \
# 3          De Gea   27       91         93  Manchester United       GK
# 9        J. Oblak   25       90         93    Atlético Madrid       GK
# 18  M. ter Stegen   26       89         92       FC Barcelona       GK
# 19    T. Courtois   26       89         90        Real Madrid       GK
# 22       M. Neuer   32       89         89  FC Bayern München       GK
#
#     Crossing  Finishing  HeadingAccuracy  ShortPassing  ...  Penalties  \
# 3       17.0       13.0             21.0          50.0  ...       40.0
# 9       13.0       11.0             15.0          29.0  ...       11.0
# 18      15.0       14.0             11.0          36.0  ...       25.0
# 19      14.0       14.0             13.0          33.0  ...       27.0
# 22      15.0       13.0             25.0          55.0  ...       47.0
#
#     Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 3        68.0     15.0            21.0           13.0      90.0        85.0
# 9        70.0     27.0            12.0           18.0      86.0        92.0
# 18       69.0     25.0            13.0           10.0      87.0        85.0
# 19       66.0     20.0            18.0           16.0      85.0        91.0
# 22       70.0     17.0            10.0           11.0      90.0        86.0
#
#     GKPositioning  GKReflexes  New Position
# 3            88.0        94.0            GK
# 9            88.0        89.0            GK
# 18           85.0        90.0            GK
# 19           86.0        88.0            GK
# 22           87.0        87.0            GK
#
# [5 rows x 40 columns]

# %%
gk19 = gk19.drop(['Name','Crossing','Finishing','HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve','FKAccuracy',
              'LongPassing','BallControl','Acceleration','SprintSpeed', 'Agility', 'Balance', 'ShotPower',
              'LongShots','Interceptions','Positioning','Vision','Penalties','Marking','StandingTackle','SlidingTackle',
             'Aggression','Stamina'],
            axis=1)

gk20 = gk20.drop(['Name','Crossing','Finishing','HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve','FKAccuracy',
              'LongPassing','BallControl','Acceleration','SprintSpeed', 'Agility', 'Balance', 'ShotPower',
              'LongShots','Interceptions','Positioning','Vision','Penalties','Marking','StandingTackle','SlidingTackle',
             'Aggression','Stamina'],
            axis=1)

# %%
gk19.columns = [str(col) + " GK" for col in gk19.columns]
gk19['Club']=gk19['Club GK']
gk19=gk19.drop(['Club GK'],axis=1)
gk20.columns = [str(col) + " GK" for col in gk20.columns]
gk20['Club']=gk20['Club GK']
gk20=gk20.drop(['Club GK'],axis=1)

# %%
gk19.head()
# Out:
#     Age GK  Overall GK  Potential GK Position GK  Reactions GK  Jumping GK  \
# 3       27          91            93          GK          90.0        67.0
# 9       25          90            93          GK          86.0        76.0
# 18      26          89            92          GK          85.0        79.0
# 19      26          89            90          GK          84.0        68.0
# 22      32          89            89          GK          84.0        77.0
#
#     Strength GK  Composure GK  GKDiving GK  GKHandling GK  GKPositioning GK  \
# 3          64.0          68.0         90.0           85.0              88.0
# 9          78.0          70.0         86.0           92.0              88.0
# 18         79.0          69.0         87.0           85.0              85.0
# 19         70.0          66.0         85.0           91.0              86.0
# 22         80.0          70.0         90.0           86.0              87.0
#
#     GKReflexes GK New Position GK               Club
# 3            94.0              GK  Manchester United
# 9            89.0              GK    Atlético Madrid
# 18           90.0              GK       FC Barcelona
# 19           88.0              GK        Real Madrid
# 22           87.0              GK  FC Bayern München

# %%
gk20.head()
# Out:
#    Position GK  Age GK  Overall GK  Potential GK  Reactions GK  Jumping GK  \
# 3           GK      26          91            91            88          78
# 8           GK      27          90            90            86          79
# 12          GK      26          89            89            88          52
# 16          GK      28          89            89            87          67
# 24          GK      25          88            88            87          66
#
#     Strength GK  Composure GK  GKDiving GK  GKHandling GK  GKPositioning GK  \
# 3            78            68           87             92                90
# 8            78            70           88             85                88
# 12           78            65           85             84                90
# 16           60            68           90             84                85
# 24           68            70           86             82                86
#
#     GKReflexes GK New Position GK               Club
# 3              89              GK    Atlético Madrid
# 8              90              GK       FC Barcelona
# 12             89              GK          Liverpool
# 16             92              GK  Manchester United
# 24             88              GK    Manchester City

# %%
gk19teams = gk19.groupby('Club').mean().sort_values('Overall GK',ascending=False)
gk19teams.head()
# Out:
#                    Age GK  Overall GK  Potential GK  Reactions GK  Jumping GK  \
# Club
# Manchester United    31.0   81.666667     82.333333     79.000000   67.666667
# Juventus             27.0   80.333333     82.666667     74.333333   72.333333
# Arsenal              29.0   79.333333     82.000000     73.666667   61.000000
# Real Madrid          27.0   79.250000     81.750000     74.000000   68.500000
# Villarreal CF        31.0   78.666667     79.000000     76.333333   71.000000
#
#                    Strength GK  Composure GK  GKDiving GK  GKHandling GK  \
# Club
# Manchester United    70.000000     63.333333    80.666667      77.666667
# Juventus             59.000000     64.666667    80.000000      78.666667
# Arsenal              67.000000     60.666667    78.333333      77.666667
# Real Madrid          68.500000     57.250000    78.500000      78.250000
# Villarreal CF        69.666667     58.666667    80.666667      75.666667
#
#                    GKPositioning GK  GKReflexes GK
# Club
# Manchester United         79.666667      84.000000
# Juventus                  79.333333      84.333333
# Arsenal                   79.333333      78.333333
# Real Madrid               77.750000      79.000000
# Villarreal CF             76.333333      80.000000

# %%
gk20teams = gk20.groupby('Club').mean().sort_values('Overall GK',ascending=False)
gk20teams.head()
# Out:
#                       Age GK  Overall GK  Potential GK  Reactions GK  \
# Club
# Juventus           31.250000   80.750000     80.750000     75.250000
# Manchester United  32.000000   80.333333     80.333333     78.666667
# FC Barcelona       25.333333   79.666667     79.666667     76.000000
# Napoli             28.333333   78.666667     78.666667     74.666667
# Villarreal CF      32.000000   78.500000     78.500000     77.000000
#
#                    Jumping GK  Strength GK  Composure GK  GKDiving GK  \
# Club
# Juventus            72.000000    61.500000     66.000000    79.750000
# Manchester United   66.666667    68.666667     63.333333    80.666667
# FC Barcelona        75.000000    65.000000     57.333333    79.666667
# Napoli              69.000000    56.333333     62.333333    80.000000
# Villarreal CF       67.500000    69.000000     60.000000    80.000000
#
#                    GKHandling GK  GKPositioning GK  GKReflexes GK
# Club
# Juventus               77.750000         82.500000      82.750000
# Manchester United      76.666667         78.333333      82.333333
# FC Barcelona           75.333333         77.000000      79.000000
# Napoli                 74.333333         77.333333      82.000000
# Villarreal CF          77.000000         77.000000      78.000000

# %%
notgk19 = df[df['New Position']!='GK']
notgk20 = fifa20[fifa20['New Position']!='GK']

# %%
notgk19.columns
# Out:
# Index(['Name', 'Age', 'Overall', 'Potential', 'Club', 'Position', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKPositioning', 'GKReflexes', 'New Position'],
#       dtype='object')

# %%
notgk19 = notgk19.drop(['Name','GKDiving','GKHandling','GKPositioning','GKReflexes'],axis=1)
notgk20 = notgk20.drop(['Name','GKDiving','GKHandling','GKPositioning','GKReflexes'],axis=1)

# %%
notgk19.head()
# Out:
#    Age  Overall  Potential                 Club Position  Crossing  Finishing  \
# 0   31       94         94         FC Barcelona       RF      84.0       95.0
# 1   33       94         94             Juventus       ST      84.0       94.0
# 2   26       92         93  Paris Saint-Germain       LW      79.0       87.0
# 4   27       91         92      Manchester City      RCM      93.0       82.0
# 5   27       91         91              Chelsea       LF      81.0       84.0
#
#    HeadingAccuracy  ShortPassing  Volleys  ...  Aggression  Interceptions  \
# 0             70.0          90.0     86.0  ...        48.0           22.0
# 1             89.0          81.0     87.0  ...        63.0           29.0
# 2             62.0          84.0     84.0  ...        56.0           36.0
# 4             55.0          92.0     82.0  ...        76.0           61.0
# 5             61.0          89.0     80.0  ...        54.0           41.0
#
#    Positioning  Vision  Penalties  Composure  Marking  StandingTackle  \
# 0         94.0    94.0       75.0       96.0     33.0            28.0
# 1         95.0    82.0       85.0       95.0     28.0            31.0
# 2         89.0    87.0       81.0       94.0     27.0            24.0
# 4         87.0    94.0       79.0       88.0     68.0            58.0
# 5         87.0    89.0       86.0       91.0     34.0            27.0
#
#    SlidingTackle  New Position
# 0           26.0             0
# 1           23.0             0
# 2           33.0             0
# 4           51.0             0
# 5           22.0             0
#
# [5 rows x 35 columns]

# %%
notgk19teams = notgk19.groupby('Club').mean().sort_values('Overall',ascending=False)
notgk20teams = notgk20.groupby('Club').mean().sort_values('Overall',ascending=False)
notgk19teams
# Out:
#                        Age    Overall  Potential   Crossing  Finishing  \
# Club
# Juventus         27.181818  82.545455  85.909091  67.318182  56.727273
# Inter            26.750000  81.050000  83.300000  67.300000  59.900000
# Napoli           25.727273  80.318182  83.590909  67.545455  58.454545
# Milan            25.043478  78.739130  82.695652  68.043478  54.608696
# FC Barcelona     23.862069  78.620690  85.724138  66.068966  60.793103
# ...                    ...        ...        ...        ...        ...
# Crewe Alexandra  23.480000  56.680000  66.080000  44.480000  41.680000
# Derry City       21.500000  55.687500  66.312500  42.312500  38.875000
# Bohemian FC      21.954545  55.318182  63.818182  46.136364  45.636364
# Limerick FC      23.235294  54.647059  60.588235  43.882353  39.705882
# Bray Wanderers   22.550000  53.750000  62.300000  45.100000  38.450000
#
#                  HeadingAccuracy  ShortPassing    Volleys  Dribbling  \
# Club
# Juventus               70.090909     75.681818  61.727273  76.818182
# Inter                  68.700000     76.250000  61.800000  76.300000
# Napoli                 62.181818     76.363636  57.909091  76.045455
# Milan                  62.304348     76.000000  59.260870  75.521739
# FC Barcelona           62.034483     77.620690  57.413793  73.241379
# ...                          ...           ...        ...        ...
# Crewe Alexandra        48.960000     51.760000  37.400000  51.080000
# Derry City             48.500000     51.437500  36.250000  50.125000
# Bohemian FC            50.409091     50.454545  40.863636  52.818182
# Limerick FC            47.882353     48.705882  40.588235  47.000000
# Bray Wanderers         52.500000     49.550000  34.500000  47.750000
#
#                      Curve  ...  LongShots  Aggression  Interceptions  \
# Club                        ...
# Juventus         66.181818  ...  64.227273   71.363636      69.545455
# Inter            63.650000  ...  66.500000   71.300000      68.050000
# Napoli           64.272727  ...  65.636364   67.772727      64.227273
# Milan            65.478261  ...  63.478261   68.260870      63.869565
# FC Barcelona     64.413793  ...  64.241379   63.034483      62.344828
# ...                    ...  ...        ...         ...            ...
# Crewe Alexandra  40.600000  ...  40.560000   49.800000      41.680000
# Derry City       42.500000  ...  38.437500   52.812500      42.812500
# Bohemian FC      44.181818  ...  44.454545   49.227273      37.409091
# Limerick FC      43.411765  ...  41.235294   51.176471      42.235294
# Bray Wanderers   37.700000  ...  38.500000   51.700000      42.200000
#
#                  Positioning     Vision  Penalties  Composure    Marking  \
# Club
# Juventus           63.227273  69.545455  61.545455  79.590909  70.000000
# Inter              67.100000  70.500000  59.700000  77.550000  69.050000
# Napoli             64.772727  67.909091  56.454545  74.454545  65.363636
# Milan              63.826087  66.782609  59.000000  74.652174  69.217391
# FC Barcelona       66.000000  70.689655  60.758621  75.068966  64.586207
# ...                      ...        ...        ...        ...        ...
# Crewe Alexandra    46.320000  46.840000  43.800000  50.680000  46.560000
# Derry City         46.687500  45.687500  41.687500  51.625000  45.437500
# Bohemian FC        49.090909  47.136364  49.363636  49.045455  37.681818
# Limerick FC        44.176471  45.764706  45.294118  49.941176  47.941176
# Bray Wanderers     44.100000  43.400000  41.900000  49.300000  42.500000
#
#                  StandingTackle  SlidingTackle
# Club
# Juventus              68.909091      66.045455
# Inter                 66.500000      64.050000
# Napoli                65.818182      63.545455
# Milan                 62.826087      60.000000
# FC Barcelona          63.241379      59.586207
# ...                         ...            ...
# Crewe Alexandra       46.120000      44.880000
# Derry City            48.250000      47.000000
# Bohemian FC           43.363636      39.545455
# Limerick FC           44.588235      44.235294
# Bray Wanderers        46.000000      43.800000
#
# [651 rows x 32 columns]

# %%
teams19=pd.merge(notgk19teams,gk19teams,'right','Club')
teams20=pd.merge(notgk20teams,gk20teams,'right','Club')

# %%
teams19 = teams19.drop(["Potential GK","Jumping GK","GKHandling GK","GKPositioning GK","Reactions GK","Composure GK","GKDiving GK","Volleys","Curve","FKAccuracy","Jumping","LongShots","Penalties",],axis=1)
teams20 = teams20.drop(["Potential GK","Jumping GK","GKHandling GK","GKPositioning GK","Reactions GK","Composure GK","GKDiving GK","Volleys","Curve","FKAccuracy","Jumping","LongShots","Penalties",],axis=1)

# %%
uk = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/UK.csv',sep=';',encoding='latin-1')
es = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/ES.csv',sep=';',encoding='latin-1')
it = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/IT.csv',sep=';',encoding='latin-1')
de = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/DE.csv',sep=';',encoding='latin-1')
be = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/BE.csv',sep=';',encoding='latin-1')
fr = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/FR.csv',sep=';',encoding='latin-1')
ne = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/NE.csv',sep=';',encoding='latin-1')
pt = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/PO.csv',sep=';',encoding='latin-1')
tr = pd.read_csv('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/europe-top-leagues-1819-results/TR.csv',sep=';',encoding='latin-1')

# %%
uk.head()
# Out:
#   Div        Date           HomeTeam           AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  10.08.2018  Manchester United     Leicester City     2     1   H     1
# 1  E0  11.08.2018        Bournemouth       Cardiff City     2     0   H     1
# 2  E0  11.08.2018             Fulham     Crystal Palace     0     2   A     0
# 3  E0  11.08.2018  Huddersfield Town            Chelsea     0     3   A     0
# 4  E0  11.08.2018   Newcastle United  Tottenham Hotspur     1     2   A     1
#
#    HTAG HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
# 0     0   H  ...   Oca.79    17  -0.75   Oca.75    1.Tem   Þub.29   Þub.21
# 1     0   H  ...   Oca.83    20  -0.75    2.Þub   Þub.13    1.Aðu   Oca.75
# 2     1   A  ...   Oca.87    22  -0.25   Þub.18    2.Kas   Oca.81   Oca.77
# 3     2   A  ...   Oca.84    23      1   Oca.84    1.Aðu   Þub.13    2.Haz
# 4     2   A  ...   Oca.81    20   0.25    2.Þub    2.Ara    1.Aðu   Oca.76
#
#      PSCH    PSCD    PSCA
# 0  Oca.55   4.Tem  Tem.69
# 1  Oca.88  Mar.61   4.Tem
# 2  Þub.62  Mar.38   2.Eyl
# 3  Tem.24  Mar.95  Oca.58
# 4  Nis.74  Mar.53  Oca.89
#
# [5 rows x 62 columns]

# %%
es.head()
# Out:
#    Div        Date       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  SP1  17.08.2018     Real Betis          Levante UD     0     3   A     0
# 1  SP1  17.08.2018      Girona FC  Real Valladolid CF     0     0   D     0
# 2  SP1  18.08.2018   FC Barcelona    Deportivo Alavés     3     0   H     0
# 3  SP1  18.08.2018       RC Celta        RCD Espanyol     1     1   D     0
# 4  SP1  18.08.2018  Villarreal CF            Sociedad     1     2   A     1
#
#    HTAG HTR  ...  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
# 0     1   A  ...     2.Haz    20  -0.75   Oca.89   Oca.85    2.Tem        2
# 1     0   D  ...    Oca.71    20  -0.75    2.Haz    2.Oca    1.Eyl   Oca.85
# 2     0   D  ...    Mar.18    19   -2.5   Oca.95   Oca.91        2   Oca.95
# 3     1   A  ...    Oca.76    18  -0.75   Þub.26   Þub.18   Oca.74   Oca.71
# 4     1   D  ...    Oca.81    18  -0.25   Oca.76   Oca.74   Þub.23   Þub.14
#
#      PSCH    PSCD    PSCA
# 0  Oca.59  Nis.42  May.89
# 1  Oca.76  Mar.57  May.62
# 2   1.Oca  Kas.85   32.17
# 3  Þub.18  Mar.26  Mar.85
# 4  Þub.32  Mar.21  Mar.53
#
# [5 rows x 61 columns]

# %%
allres = uk.append([be,de,tr,es,ne,fr,pt,it])
allres['Div'].unique()
# Out:
# C:\Users\Mehak\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# array(['E0', 'B1', 'D1', 'T1', 'SP1', 'N1', 'F1', 'P1', 'I1'],
#       dtype=object)

# %%
allres=allres[['HomeTeam','AwayTeam','FTHG','FTAG','FTR']]
allres.head()
# Out:
#             HomeTeam           AwayTeam  FTHG  FTAG FTR
# 0  Manchester United     Leicester City     2     1   H
# 1        Bournemouth       Cardiff City     2     0   H
# 2             Fulham     Crystal Palace     0     2   A
# 3  Huddersfield Town            Chelsea     0     3   A
# 4   Newcastle United  Tottenham Hotspur     1     2   A

# %%
allres['HomeTeam'].describe()
# Out:
# count                 2984
# unique                 168
# top       AS Saint-Étienne
# freq                    19
# Name: HomeTeam, dtype: object

# %%
HomeStats = teams19
HomeStats = HomeStats.add_prefix('Home ')
HomeStats = HomeStats.reset_index()
AwayStats = teams19
AwayStats = AwayStats.add_prefix('Away ')
AwayStats = AwayStats.reset_index()

# %%
HomeStats.head()
# Out:
#            Club   Home Age  Home Overall  Home Potential  Home Crossing  \
# 0      Juventus  27.181818     82.545455       85.909091      67.318182
# 1         Inter  26.750000     81.050000       83.300000      67.300000
# 2        Napoli  25.727273     80.318182       83.590909      67.545455
# 3         Milan  25.043478     78.739130       82.695652      68.043478
# 4  FC Barcelona  23.862069     78.620690       85.724138      66.068966
#
#    Home Finishing  Home HeadingAccuracy  Home ShortPassing  Home Dribbling  \
# 0       56.727273             70.090909          75.681818       76.818182
# 1       59.900000             68.700000          76.250000       76.300000
# 2       58.454545             62.181818          76.363636       76.045455
# 3       54.608696             62.304348          76.000000       75.521739
# 4       60.793103             62.034483          77.620690       73.241379
#
#    Home LongPassing  ...  Home Positioning  Home Vision  Home Composure  \
# 0         69.954545  ...         63.227273    69.545455       79.590909
# 1         71.350000  ...         67.100000    70.500000       77.550000
# 2         69.636364  ...         64.772727    67.909091       74.454545
# 3         69.478261  ...         63.826087    66.782609       74.652174
# 4         70.448276  ...         66.000000    70.689655       75.068966
#
#    Home Marking  Home StandingTackle  Home SlidingTackle  Home Age GK  \
# 0     70.000000            68.909091           66.045455    27.000000
# 1     69.050000            66.500000           64.050000    31.000000
# 2     65.363636            65.818182           63.545455    27.333333
# 3     69.217391            62.826087           60.000000    24.750000
# 4     64.586207            63.241379           59.586207    23.750000
#
#    Home Overall GK  Home Strength GK  Home GKReflexes GK
# 0        80.333333         59.000000           84.333333
# 1        73.250000         52.250000           74.750000
# 2        77.666667         56.333333           81.333333
# 3        74.250000         68.250000           79.000000
# 4        73.750000         66.000000           74.000000
#
# [5 rows x 31 columns]

# %%
AwayStats.head()
# Out:
#            Club   Away Age  Away Overall  Away Potential  Away Crossing  \
# 0      Juventus  27.181818     82.545455       85.909091      67.318182
# 1         Inter  26.750000     81.050000       83.300000      67.300000
# 2        Napoli  25.727273     80.318182       83.590909      67.545455
# 3         Milan  25.043478     78.739130       82.695652      68.043478
# 4  FC Barcelona  23.862069     78.620690       85.724138      66.068966
#
#    Away Finishing  Away HeadingAccuracy  Away ShortPassing  Away Dribbling  \
# 0       56.727273             70.090909          75.681818       76.818182
# 1       59.900000             68.700000          76.250000       76.300000
# 2       58.454545             62.181818          76.363636       76.045455
# 3       54.608696             62.304348          76.000000       75.521739
# 4       60.793103             62.034483          77.620690       73.241379
#
#    Away LongPassing  ...  Away Positioning  Away Vision  Away Composure  \
# 0         69.954545  ...         63.227273    69.545455       79.590909
# 1         71.350000  ...         67.100000    70.500000       77.550000
# 2         69.636364  ...         64.772727    67.909091       74.454545
# 3         69.478261  ...         63.826087    66.782609       74.652174
# 4         70.448276  ...         66.000000    70.689655       75.068966
#
#    Away Marking  Away StandingTackle  Away SlidingTackle  Away Age GK  \
# 0     70.000000            68.909091           66.045455    27.000000
# 1     69.050000            66.500000           64.050000    31.000000
# 2     65.363636            65.818182           63.545455    27.333333
# 3     69.217391            62.826087           60.000000    24.750000
# 4     64.586207            63.241379           59.586207    23.750000
#
#    Away Overall GK  Away Strength GK  Away GKReflexes GK
# 0        80.333333         59.000000           84.333333
# 1        73.250000         52.250000           74.750000
# 2        77.666667         56.333333           81.333333
# 3        74.250000         68.250000           79.000000
# 4        73.750000         66.000000           74.000000
#
# [5 rows x 31 columns]

# %%
res1 = pd.merge(allres,HomeStats,'left',left_on='HomeTeam',right_on='Club')
res1.head()
alltable = pd.merge(res1, AwayStats, 'left',left_on='AwayTeam',right_on='Club')

# %%
nan = alltable[alltable['Club_x'].isna()]
nan['HomeTeam'].unique()
# Out:
# array(['FC Schalke 04 04', 'Beþiktaþ JK', 'Medipol Baþakþehir FK',
#        'Kasimpaþa SK', 'Sociedad', 'Spal'], dtype=object)

# %%
allres['HomeTeam'] = allres['HomeTeam'].replace('FC Schalke 04 04', 'FC Schalke 04')
allres['AwayTeam'] =  allres['AwayTeam'].replace('FC Schalke 04 04', 'FC Schalke 04')
allres['HomeTeam'] =  allres['HomeTeam'].replace('Medipol Baþakþehir FK', 'Medipol Başakşehir FK')
allres['AwayTeam'] =  allres['AwayTeam'].replace('Medipol Baþakþehir FK', 'Medipol Başakşehir FK')
allres['HomeTeam'] = allres['HomeTeam'].replace('Beþiktaþ JK', 'Beşiktaş JK')
allres['AwayTeam'] = allres['AwayTeam'].replace('Beþiktaþ JK', 'Beşiktaş JK')
allres['HomeTeam'] = allres['HomeTeam'].replace('Sociedad', 'Real Sociedad')
allres['AwayTeam'] = allres['AwayTeam'].replace('Sociedad', 'Real Sociedad')
allres['HomeTeam'] = allres['HomeTeam'].replace('Spal', 'SPAL')
allres['AwayTeam'] = allres['AwayTeam'].replace('Spal', 'SPAL')
allres['HomeTeam'] = allres['HomeTeam'].replace('Kasimpaþa SK', 'Kasimpaşa SK')
allres['AwayTeam'] = allres['AwayTeam'].replace('Kasimpaþa SK', 'Kasimpaşa SK')

# %%
res1 = pd.merge(allres,HomeStats,'left',left_on='HomeTeam',right_on='Club')
alltable2 = pd.merge(res1, AwayStats, 'left',left_on='AwayTeam',right_on='Club')

# %%
nan2 = alltable2[alltable2['Club_x'].isna()]
nan2['Club_x'].unique()
# Out:
# array([], dtype=object)

# %%
nan2 = alltable2[alltable2['Club_y'].isna()]
nan2['Club_y'].unique()
# Out:
# array([], dtype=object)

# %%
alltable2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2984 entries, 0 to 2983
# Data columns (total 67 columns):
# HomeTeam                2984 non-null object
# AwayTeam                2984 non-null object
# FTHG                    2984 non-null int64
# FTAG                    2984 non-null int64
# FTR                     2984 non-null object
# Club_x                  2984 non-null object
# Home Age                2984 non-null float64
# Home Overall            2984 non-null float64
# Home Potential          2984 non-null float64
# Home Crossing           2984 non-null float64
# Home Finishing          2984 non-null float64
# Home HeadingAccuracy    2984 non-null float64
# Home ShortPassing       2984 non-null float64
# Home Dribbling          2984 non-null float64
# Home LongPassing        2984 non-null float64
# Home BallControl        2984 non-null float64
# Home Acceleration       2984 non-null float64
# Home SprintSpeed        2984 non-null float64
# Home Agility            2984 non-null float64
# Home Reactions          2984 non-null float64
# Home Balance            2984 non-null float64
# Home ShotPower          2984 non-null float64
# Home Stamina            2984 non-null float64
# Home Strength           2984 non-null float64
# Home Aggression         2984 non-null float64
# Home Interceptions      2984 non-null float64
# Home Positioning        2984 non-null float64
# Home Vision             2984 non-null float64
# Home Composure          2984 non-null float64
# Home Marking            2984 non-null float64
# Home StandingTackle     2984 non-null float64
# Home SlidingTackle      2984 non-null float64
# Home Age GK             2984 non-null float64
# Home Overall GK         2984 non-null float64
# Home Strength GK        2984 non-null float64
# Home GKReflexes GK      2984 non-null float64
# Club_y                  2984 non-null object
# Away Age                2984 non-null float64
# Away Overall            2984 non-null float64
# Away Potential          2984 non-null float64
# Away Crossing           2984 non-null float64
# Away Finishing          2984 non-null float64
# Away HeadingAccuracy    2984 non-null float64
# Away ShortPassing       2984 non-null float64
# Away Dribbling          2984 non-null float64
# Away LongPassing        2984 non-null float64
# Away BallControl        2984 non-null float64
# Away Acceleration       2984 non-null float64
# Away SprintSpeed        2984 non-null float64
# Away Agility            2984 non-null float64
# Away Reactions          2984 non-null float64
# Away Balance            2984 non-null float64
# Away ShotPower          2984 non-null float64
# Away Stamina            2984 non-null float64
# Away Strength           2984 non-null float64
# Away Aggression         2984 non-null float64
# Away Interceptions      2984 non-null float64
# Away Positioning        2984 non-null float64
# Away Vision             2984 non-null float64
# Away Composure          2984 non-null float64
# Away Marking            2984 non-null float64
# Away StandingTackle     2984 non-null float64
# Away SlidingTackle      2984 non-null float64
# Away Age GK             2984 non-null float64
# Away Overall GK         2984 non-null float64
# Away Strength GK        2984 non-null float64
# Away GKReflexes GK      2984 non-null float64
# dtypes: float64(60), int64(2), object(5)
# memory usage: 1.5+ MB

# %%
alltable2.describe()
# Out:
#               FTHG         FTAG     Home Age  Home Overall  Home Potential  \
# count  2984.000000  2984.000000  2984.000000   2984.000000     2984.000000
# mean      1.591823     1.231233    24.681326     71.239423       76.357645
# std       1.326999     1.187211     1.414044      3.623076        3.973312
# min       0.000000     0.000000    20.636364     62.037037       67.444444
# 25%       1.000000     0.000000    23.640000     68.827586       72.909091
# 50%       1.000000     1.000000    24.642857     70.923077       76.535714
# 75%       2.000000     2.000000    25.518519     73.300000       79.045455
# max      10.000000     8.000000    28.769231     82.545455       85.909091
#
#        Home Crossing  Home Finishing  Home HeadingAccuracy  Home ShortPassing  \
# count    2984.000000     2984.000000           2984.000000        2984.000000
# mean       59.180468       53.398149             60.897618          67.932143
# std         3.857652        3.839116              3.254702           3.917067
# min        50.814815       44.909091             51.833333          59.846154
# 25%        56.640000       50.783750             58.888889          65.043478
# 50%        59.000000       53.041667             61.133333          67.416667
# 75%        61.777778       55.925926             63.000000          70.571429
# max        68.518519       63.565217             70.090909          77.620690
#
#        Home Dribbling  ...  Away Positioning  Away Vision  Away Composure  \
# count     2984.000000  ...       2984.000000  2984.000000     2984.000000
# mean        66.168235  ...         58.944676    59.962393       65.906909
# std          3.861615  ...          3.745069     4.189444        4.326736
# min         57.227273  ...         48.739130    51.814815       55.074074
# 25%         63.291667  ...         56.509565    56.962963       62.565217
# 50%         65.818182  ...         58.590909    59.518519       65.666667
# 75%         68.222222  ...         61.208333    62.208333       68.708333
# max         76.818182  ...         67.680000    70.689655       79.590909
#
#        Away Marking  Away StandingTackle  Away SlidingTackle  Away Age GK  \
# count   2984.000000          2984.000000         2984.000000  2984.000000
# mean      54.963787            55.910584           53.278793    26.155881
# std        4.980450             4.042019            3.889784     2.655720
# min       44.880000            47.280000           42.956522    19.500000
# 25%       51.355364            52.923913           50.482759    24.500000
# 50%       54.318182            55.703704           52.896552    25.750000
# 75%       58.428571            58.478261           55.888889    27.500000
# max       70.000000            68.909091           66.045455    34.500000
#
#        Away Overall GK  Away Strength GK  Away GKReflexes GK
# count      2984.000000       2984.000000         2984.000000
# mean         69.755529         62.529999           71.426642
# std           4.101580          6.008129            4.535860
# min          59.666667         46.000000           59.750000
# 25%          67.000000         58.333333           68.000000
# 50%          69.750000         62.333333           71.666667
# 75%          72.333333         67.333333           74.666667
# max          81.666667         78.000000           84.333333
#
# [8 rows x 62 columns]

# %%
table = alltable2.drop(columns=['HomeTeam','AwayTeam','Club_x','Club_y'])
table.head()
# Out:
#    FTHG  FTAG FTR   Home Age  Home Overall  Home Potential  Home Crossing  \
# 0     2     1   H  24.133333     76.800000       82.700000      66.900000
# 1     2     0   H  23.827586     69.689655       75.896552      58.379310
# 2     0     2   A  23.142857     69.250000       76.535714      54.000000
# 3     0     3   A  23.206897     69.103448       76.103448      58.551724
# 4     1     2   A  24.172414     70.758621       77.448276      57.620690
#
#    Home Finishing  Home HeadingAccuracy  Home ShortPassing  ...  \
# 0       60.600000             66.966667          74.233333  ...
# 1       52.000000             57.758621          65.517241  ...
# 2       52.500000             59.821429          66.642857  ...
# 3       51.517241             62.965517          64.482759  ...
# 4       54.034483             62.275862          67.000000  ...
#
#    Away Positioning  Away Vision  Away Composure  Away Marking  \
# 0         62.482759    62.172414       67.551724     61.137931
# 1         57.366667    57.200000       60.200000     48.433333
# 2         57.620690    59.689655       64.827586     55.793103
# 3         64.482759    70.172414       74.241379     59.827586
# 4         66.724138    67.896552       72.896552     61.551724
#
#    Away StandingTackle  Away SlidingTackle  Away Age GK  Away Overall GK  \
# 0            62.620690           59.172414    29.666667        76.333333
# 1            51.700000           49.666667    30.333333        70.000000
# 2            57.586207           54.862069    33.666667        74.333333
# 3            61.586207           58.931034    28.750000        71.750000
# 4            61.724138           57.862069    27.500000        75.000000
#
#    Away Strength GK  Away GKReflexes GK
# 0         62.000000           79.000000
# 1         61.000000           71.666667
# 2         57.666667           74.333333
# 3         62.250000           73.250000
# 4         55.750000           77.500000
#
# [5 rows x 63 columns]

# %%
table['FTR']= table['FTR'].replace(['H','A','D'],[1,2,0])
table.head()
# Out:
#    FTHG  FTAG  FTR   Home Age  Home Overall  Home Potential  Home Crossing  \
# 0     2     1    1  24.133333     76.800000       82.700000      66.900000
# 1     2     0    1  23.827586     69.689655       75.896552      58.379310
# 2     0     2    2  23.142857     69.250000       76.535714      54.000000
# 3     0     3    2  23.206897     69.103448       76.103448      58.551724
# 4     1     2    2  24.172414     70.758621       77.448276      57.620690
#
#    Home Finishing  Home HeadingAccuracy  Home ShortPassing  ...  \
# 0       60.600000             66.966667          74.233333  ...
# 1       52.000000             57.758621          65.517241  ...
# 2       52.500000             59.821429          66.642857  ...
# 3       51.517241             62.965517          64.482759  ...
# 4       54.034483             62.275862          67.000000  ...
#
#    Away Positioning  Away Vision  Away Composure  Away Marking  \
# 0         62.482759    62.172414       67.551724     61.137931
# 1         57.366667    57.200000       60.200000     48.433333
# 2         57.620690    59.689655       64.827586     55.793103
# 3         64.482759    70.172414       74.241379     59.827586
# 4         66.724138    67.896552       72.896552     61.551724
#
#    Away StandingTackle  Away SlidingTackle  Away Age GK  Away Overall GK  \
# 0            62.620690           59.172414    29.666667        76.333333
# 1            51.700000           49.666667    30.333333        70.000000
# 2            57.586207           54.862069    33.666667        74.333333
# 3            61.586207           58.931034    28.750000        71.750000
# 4            61.724138           57.862069    27.500000        75.000000
#
#    Away Strength GK  Away GKReflexes GK
# 0         62.000000           79.000000
# 1         61.000000           71.666667
# 2         57.666667           74.333333
# 3         62.250000           73.250000
# 4         55.750000           77.500000
#
# [5 rows x 63 columns]

# %%
tablek=table.iloc[:,2:]
tablek.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2984 entries, 0 to 2983
# Data columns (total 61 columns):
# FTR                     2984 non-null int64
# Home Age                2984 non-null float64
# Home Overall            2984 non-null float64
# Home Potential          2984 non-null float64
# Home Crossing           2984 non-null float64
# Home Finishing          2984 non-null float64
# Home HeadingAccuracy    2984 non-null float64
# Home ShortPassing       2984 non-null float64
# Home Dribbling          2984 non-null float64
# Home LongPassing        2984 non-null float64
# Home BallControl        2984 non-null float64
# Home Acceleration       2984 non-null float64
# Home SprintSpeed        2984 non-null float64
# Home Agility            2984 non-null float64
# Home Reactions          2984 non-null float64
# Home Balance            2984 non-null float64
# Home ShotPower          2984 non-null float64
# Home Stamina            2984 non-null float64
# Home Strength           2984 non-null float64
# Home Aggression         2984 non-null float64
# Home Interceptions      2984 non-null float64
# Home Positioning        2984 non-null float64
# Home Vision             2984 non-null float64
# Home Composure          2984 non-null float64
# Home Marking            2984 non-null float64
# Home StandingTackle     2984 non-null float64
# Home SlidingTackle      2984 non-null float64
# Home Age GK             2984 non-null float64
# Home Overall GK         2984 non-null float64
# Home Strength GK        2984 non-null float64
# Home GKReflexes GK      2984 non-null float64
# Away Age                2984 non-null float64
# Away Overall            2984 non-null float64
# Away Potential          2984 non-null float64
# Away Crossing           2984 non-null float64
# Away Finishing          2984 non-null float64
# Away HeadingAccuracy    2984 non-null float64
# Away ShortPassing       2984 non-null float64
# Away Dribbling          2984 non-null float64
# Away LongPassing        2984 non-null float64
# Away BallControl        2984 non-null float64
# Away Acceleration       2984 non-null float64
# Away SprintSpeed        2984 non-null float64
# Away Agility            2984 non-null float64
# Away Reactions          2984 non-null float64
# Away Balance            2984 non-null float64
# Away ShotPower          2984 non-null float64
# Away Stamina            2984 non-null float64
# Away Strength           2984 non-null float64
# Away Aggression         2984 non-null float64
# Away Interceptions      2984 non-null float64
# Away Positioning        2984 non-null float64
# Away Vision             2984 non-null float64
# Away Composure          2984 non-null float64
# Away Marking            2984 non-null float64
# Away StandingTackle     2984 non-null float64
# Away SlidingTackle      2984 non-null float64
# Away Age GK             2984 non-null float64
# Away Overall GK         2984 non-null float64
# Away Strength GK        2984 non-null float64
# Away GKReflexes GK      2984 non-null float64
# dtypes: float64(60), int64(1)
# memory usage: 1.4 MB

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(tablek.iloc[:,1:])
scaled_feat=scaler.transform(tablek.iloc[:,1:])
tablek_feat=pd.DataFrame(scaled_feat,tablek.iloc[:,1:])
X = tablek_feat
y=tablek['FTR']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=8)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
pred=knn.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[ 82  85  48]
#  [136 220  56]
#  [ 93  66 110]]
#               precision    recall  f1-score   support
#
#            0       0.26      0.38      0.31       215
#            1       0.59      0.53      0.56       412
#            2       0.51      0.41      0.46       269
#
#     accuracy                           0.46       896
#    macro avg       0.46      0.44      0.44       896
# weighted avg       0.49      0.46      0.47       896

# %%
error_rate=[]

for i in range(1,50):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

mat.figure(figsize=(10,6))
mat.plot(range(1,50),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
mat.title('Error Rate vs. K Value')
mat.xlabel('K')
mat.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn import metrics
k_range= range(1,50)

scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

print(scores)

mat.plot(k_range, scores)
mat.xlabel('Value of K for KNN')
mat.ylabel('Testing Accuracy')
# Out:
# [0.42299107142857145, 0.3984375, 0.45982142857142855, 0.48660714285714285, 0.47879464285714285, 0.4877232142857143, 0.5133928571428571, 0.5066964285714286, 0.5245535714285714, 0.5189732142857143, 0.5178571428571429, 0.546875, 0.5301339285714286, 0.5412946428571429, 0.5357142857142857, 0.5513392857142857, 0.5390625, 0.5424107142857143, 0.5457589285714286, 0.5345982142857143, 0.5390625, 0.5412946428571429, 0.5457589285714286, 0.546875, 0.5401785714285714, 0.5435267857142857, 0.5401785714285714, 0.53125, 0.5345982142857143, 0.5379464285714286, 0.5357142857142857, 0.5457589285714286, 0.5435267857142857, 0.5357142857142857, 0.5424107142857143, 0.5424107142857143, 0.5334821428571429, 0.5368303571428571, 0.5379464285714286, 0.5345982142857143, 0.5357142857142857, 0.5390625, 0.5412946428571429, 0.5334821428571429, 0.5301339285714286, 0.5357142857142857, 0.5323660714285714, 0.5334821428571429, 0.5323660714285714]
# Text(0, 0.5, 'Testing Accuracy')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train,y_train)
pred=knn.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[ 44 110  61]
#  [ 50 307  55]
#  [ 38 102 129]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.20      0.25       215
#            1       0.59      0.75      0.66       412
#            2       0.53      0.48      0.50       269
#
#     accuracy                           0.54       896
#    macro avg       0.48      0.48      0.47       896
# weighted avg       0.51      0.54      0.51       896

# %%
cl = pd.read_excel('C:/Users/Mehak/Documents/Python for Data Science/Projects/Predicting Champions League Group Standings/champions-league-groups-1920/clgroups1920.xlsx', header=0)
table1=pd.merge(cl, HomeStats,'left', left_on='HomeTeam',right_on='Club')
clmatches=pd.merge(table1, AwayStats,'left',left_on='AwayTeam',right_on='Club')
clmatches
# Out:
#    Group              HomeTeam        AwayTeam               Club_x  \
# 0       A  Paris Saint-Germain     Real Madrid  Paris Saint-Germain
# 1       A       Club Brugge KV  Galatasaray SK       Club Brugge KV
# 2       A  Paris Saint-Germain  Club Brugge KV  Paris Saint-Germain
# 3       A          Real Madrid  Galatasaray SK          Real Madrid
# 4       A  Paris Saint-Germain  Galatasaray SK  Paris Saint-Germain
# ..    ...                  ...             ...                  ...
# 79      H           LOSC Lille     Valencia CF           LOSC Lille
# 80      H           LOSC Lille         Chelsea           LOSC Lille
# 81      H                 Ajax     Valencia CF                 Ajax
# 82      H          Valencia CF         Chelsea          Valencia CF
# 83      H           LOSC Lille            Ajax           LOSC Lille
#
#      Home Age  Home Overall  Home Potential  Home Crossing  Home Finishing  \
# 0   24.148148     77.481481       83.518519      68.518519       58.222222
# 1   22.880000     71.840000       79.160000      58.200000       54.800000
# 2   24.148148     77.481481       83.518519      68.518519       58.222222
# 3   23.620690     78.103448       85.034483      64.586207       58.586207
# 4   24.148148     77.481481       83.518519      68.518519       58.222222
# ..        ...           ...             ...            ...             ...
# 79  22.090909     69.818182       79.045455      59.590909       49.409091
# 80  22.090909     69.818182       79.045455      59.590909       49.409091
# 81  22.178571     73.428571       80.250000      64.500000       59.821429
# 82  23.034483     75.068966       81.758621      65.724138       58.517241
# 83  22.090909     69.818182       79.045455      59.590909       49.409091
#
#     Home HeadingAccuracy  ...  Away Positioning  Away Vision  Away Composure  \
# 0              64.407407  ...         63.793103    65.827586       72.103448
# 1              63.800000  ...         58.888889    62.000000       64.185185
# 2              64.407407  ...         59.560000    60.080000       66.560000
# 3              63.379310  ...         58.888889    62.000000       64.185185
# 4              64.407407  ...         58.888889    62.000000       64.185185
# ..                   ...  ...               ...          ...             ...
# 79             57.590909  ...         62.034483    64.724138       67.310345
# 80             57.590909  ...         64.482759    70.172414       74.241379
# 81             62.500000  ...         62.034483    64.724138       67.310345
# 82             62.724138  ...         64.482759    70.172414       74.241379
# 83             57.590909  ...         63.357143    68.250000       70.678571
#
#     Away Marking  Away StandingTackle  Away SlidingTackle  Away Age GK  \
# 0      61.896552            61.793103           58.586207    27.000000
# 1      53.222222            55.444444           52.777778    24.666667
# 2      57.160000            55.240000           52.440000    22.666667
# 3      53.222222            55.444444           52.777778    24.666667
# 4      53.222222            55.444444           52.777778    24.666667
# ..           ...                  ...                 ...          ...
# 79     58.448276            58.275862           57.034483    23.250000
# 80     59.827586            61.586207           58.931034    28.750000
# 81     58.448276            58.275862           57.034483    23.250000
# 82     59.827586            61.586207           58.931034    28.750000
# 83     54.035714            55.750000           50.607143    24.000000
#
#     Away Overall GK  Away Strength GK  Away GKReflexes GK
# 0         79.250000         68.500000               79.00
# 1         68.333333         61.666667               71.00
# 2         70.333333         67.666667               73.00
# 3         68.333333         61.666667               71.00
# 4         68.333333         61.666667               71.00
# ..              ...               ...                 ...
# 79        72.000000         59.500000               75.25
# 80        71.750000         62.250000               73.25
# 81        72.000000         59.500000               75.25
# 82        71.750000         62.250000               73.25
# 83        76.500000         54.500000               79.00
#
# [84 rows x 65 columns]

# %%
clmatches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 83
# Data columns (total 65 columns):
# Group                   84 non-null object
# HomeTeam                84 non-null object
# AwayTeam                84 non-null object
# Club_x                  84 non-null object
# Home Age                84 non-null float64
# Home Overall            84 non-null float64
# Home Potential          84 non-null float64
# Home Crossing           84 non-null float64
# Home Finishing          84 non-null float64
# Home HeadingAccuracy    84 non-null float64
# Home ShortPassing       84 non-null float64
# Home Dribbling          84 non-null float64
# Home LongPassing        84 non-null float64
# Home BallControl        84 non-null float64
# Home Acceleration       84 non-null float64
# Home SprintSpeed        84 non-null float64
# Home Agility            84 non-null float64
# Home Reactions          84 non-null float64
# Home Balance            84 non-null float64
# Home ShotPower          84 non-null float64
# Home Stamina            84 non-null float64
# Home Strength           84 non-null float64
# Home Aggression         84 non-null float64
# Home Interceptions      84 non-null float64
# Home Positioning        84 non-null float64
# Home Vision             84 non-null float64
# Home Composure          84 non-null float64
# Home Marking            84 non-null float64
# Home StandingTackle     84 non-null float64
# Home SlidingTackle      84 non-null float64
# Home Age GK             84 non-null float64
# Home Overall GK         84 non-null float64
# Home Strength GK        84 non-null float64
# Home GKReflexes GK      84 non-null float64
# Club_y                  84 non-null object
# Away Age                84 non-null float64
# Away Overall            84 non-null float64
# Away Potential          84 non-null float64
# Away Crossing           84 non-null float64
# Away Finishing          84 non-null float64
# Away HeadingAccuracy    84 non-null float64
# Away ShortPassing       84 non-null float64
# Away Dribbling          84 non-null float64
# Away LongPassing        84 non-null float64
# Away BallControl        84 non-null float64
# Away Acceleration       84 non-null float64
# Away SprintSpeed        84 non-null float64
# Away Agility            84 non-null float64
# Away Reactions          84 non-null float64
# Away Balance            84 non-null float64
# Away ShotPower          84 non-null float64
# Away Stamina            84 non-null float64
# Away Strength           84 non-null float64
# Away Aggression         84 non-null float64
# Away Interceptions      84 non-null float64
# Away Positioning        84 non-null float64
# Away Vision             84 non-null float64
# Away Composure          84 non-null float64
# Away Marking            84 non-null float64
# Away StandingTackle     84 non-null float64
# Away SlidingTackle      84 non-null float64
# Away Age GK             84 non-null float64
# Away Overall GK         84 non-null float64
# Away Strength GK        84 non-null float64
# Away GKReflexes GK      84 non-null float64
# dtypes: float64(60), object(5)
# memory usage: 43.3+ KB

# %%
clmatches=clmatches.drop(['Club_x','Club_y'],axis=1)
clmatches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 83
# Data columns (total 63 columns):
# Group                   84 non-null object
# HomeTeam                84 non-null object
# AwayTeam                84 non-null object
# Home Age                84 non-null float64
# Home Overall            84 non-null float64
# Home Potential          84 non-null float64
# Home Crossing           84 non-null float64
# Home Finishing          84 non-null float64
# Home HeadingAccuracy    84 non-null float64
# Home ShortPassing       84 non-null float64
# Home Dribbling          84 non-null float64
# Home LongPassing        84 non-null float64
# Home BallControl        84 non-null float64
# Home Acceleration       84 non-null float64
# Home SprintSpeed        84 non-null float64
# Home Agility            84 non-null float64
# Home Reactions          84 non-null float64
# Home Balance            84 non-null float64
# Home ShotPower          84 non-null float64
# Home Stamina            84 non-null float64
# Home Strength           84 non-null float64
# Home Aggression         84 non-null float64
# Home Interceptions      84 non-null float64
# Home Positioning        84 non-null float64
# Home Vision             84 non-null float64
# Home Composure          84 non-null float64
# Home Marking            84 non-null float64
# Home StandingTackle     84 non-null float64
# Home SlidingTackle      84 non-null float64
# Home Age GK             84 non-null float64
# Home Overall GK         84 non-null float64
# Home Strength GK        84 non-null float64
# Home GKReflexes GK      84 non-null float64
# Away Age                84 non-null float64
# Away Overall            84 non-null float64
# Away Potential          84 non-null float64
# Away Crossing           84 non-null float64
# Away Finishing          84 non-null float64
# Away HeadingAccuracy    84 non-null float64
# Away ShortPassing       84 non-null float64
# Away Dribbling          84 non-null float64
# Away LongPassing        84 non-null float64
# Away BallControl        84 non-null float64
# Away Acceleration       84 non-null float64
# Away SprintSpeed        84 non-null float64
# Away Agility            84 non-null float64
# Away Reactions          84 non-null float64
# Away Balance            84 non-null float64
# Away ShotPower          84 non-null float64
# Away Stamina            84 non-null float64
# Away Strength           84 non-null float64
# Away Aggression         84 non-null float64
# Away Interceptions      84 non-null float64
# Away Positioning        84 non-null float64
# Away Vision             84 non-null float64
# Away Composure          84 non-null float64
# Away Marking            84 non-null float64
# Away StandingTackle     84 non-null float64
# Away SlidingTackle      84 non-null float64
# Away Age GK             84 non-null float64
# Away Overall GK         84 non-null float64
# Away Strength GK        84 non-null float64
# Away GKReflexes GK      84 non-null float64
# dtypes: float64(60), object(3)
# memory usage: 42.0+ KB

# %%
scaler.fit(clmatches.iloc[:,3:])
scaled_feat=scaler.transform(clmatches.iloc[:,3:])
tablecl_feat=pd.DataFrame(scaled_feat,clmatches.iloc[:,3:])
Xcl = tablecl_feat
predcl=knn.predict(Xcl)

# %%
clmatches['Results']=predcl
clresults=clmatches[['Group ','HomeTeam','AwayTeam','Results']]
clresults['Homepts']=0
clresults['Awaypts']=0
clresults['Homepts'][clresults['Results']==1]=3
clresults['Awaypts'][clresults['Results']==2]=3
clresults['Homepts'][clresults['Results']==0]=1
clresults['Awaypts'][clresults['Results']==0]=1
clresults[clresults['Group ']=='A']
# Out:
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Mehak\Anaconda3\lib\site-packages\pandas\core\generic.py:9114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Users\Mehak\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Mehak\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Group              HomeTeam             AwayTeam  Results  Homepts  Awaypts
# 0       A  Paris Saint-Germain          Real Madrid        1        3        0
# 1       A       Club Brugge KV       Galatasaray SK        0        1        1
# 2       A  Paris Saint-Germain       Club Brugge KV        1        3        0
# 3       A          Real Madrid       Galatasaray SK        1        3        0
# 4       A  Paris Saint-Germain       Galatasaray SK        1        3        0
# 5       A          Real Madrid       Club Brugge KV        1        3        0
# 6       A          Real Madrid  Paris Saint-Germain        1        3        0
# 7       A       Galatasaray SK       Club Brugge KV        1        3        0
# 8       A       Club Brugge KV  Paris Saint-Germain        2        0        3
# 9       A       Galatasaray SK          Real Madrid        2        0        3
# 10      A       Galatasaray SK  Paris Saint-Germain        1        3        0
# 11      A       Club Brugge KV          Real Madrid        2        0        3

# %%
hpts=clresults.groupby(['Group ','HomeTeam']).sum()
hpts=hpts.drop(['Awaypts','Results'],axis=1)
apts=clresults.groupby(['Group ','AwayTeam']).sum()
apts=apts.drop(['Homepts','Results'],axis=1)

# %%
hpts.reset_index(inplace=True)
apts.reset_index(inplace=True)
clpred = pd.concat([hpts,apts],axis=1)
clpred['Total Points']=clpred['Homepts']+clpred['Awaypts']
clpred=clpred.drop(columns=['Homepts','Awaypts','AwayTeam'],axis=1)
clpred=clpred.iloc[:,~clpred.columns.duplicated()]
clpred=clpred.groupby(['Group ','HomeTeam']).sum()
clpred.sort_values(['Group ','Total Points'],ascending=False).groupby('Group ').head(4)
# Out:
#                              Total Points
# Group  HomeTeam
# H      Valencia CF                     13
#        Chelsea                         10
#        Ajax                             8
#        LOSC Lille                       1
# G      SL Benfica                       9
#        Olympique Lyonnais               6
#        RB Leipzig                       3
# F      Inter                           15
#        Borussia Dortmund               10
#        FC Barcelona                     4
#        SK Slavia Praha                  3
# E      Liverpool                       15
#        Napoli                          12
#        FC Barcelona                     3
#        FC Red Bull Salzburg             3
# D      Juventus                        18
#        Bayer 04 Leverkusen              9
#        Atlético Madrid                  4
#        Napoli                           4
# C      Manchester City                 15
#        Shakhtar Donetsk                12
#        Dinamo Zagreb                    6
#        Atalanta                         3
# B      Tottenham Hotspur               12
#        FC Bayern München                4
#        Olympiacos CFP                   1
# A      Real Madrid                     15
#        Paris Saint-Germain             12
#        Galatasaray SK                   7
#        Club Brugge KV                   1

# %%
clpred.sort_values(['Group ','Total Points'],ascending=False).groupby('Group ').head(2)
# Out:
#                             Total Points
# Group  HomeTeam
# H      Valencia CF                    13
#        Chelsea                        10
# G      SL Benfica                      9
#        Olympique Lyonnais              6
# F      Inter                          15
#        Borussia Dortmund              10
# E      Liverpool                      15
#        Napoli                         12
# D      Juventus                       18
#        Bayer 04 Leverkusen             9
# C      Manchester City                15
#        Shakhtar Donetsk               12
# B      Tottenham Hotspur              12
#        FC Bayern München               4
# A      Real Madrid                    15
#        Paris Saint-Germain            12
